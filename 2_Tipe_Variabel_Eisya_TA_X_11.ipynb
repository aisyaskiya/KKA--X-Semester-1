# %% [markdown]
# <a href="https://colab.research.google.com/github/aisyaskiya/KKA--X-Semester-1/blob/main/2_Tipe_Variabel_Eisya_TA_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama :Eisya Tifa Adzkia
#
# Kelas: X.11
#
# No.absen: 12

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("eisyatifaa.2025@gmail.com")
print("eisyatifaa.2025@gmail.com")
print("eisyatifaa.2025@gmail.com")
# Out:
# eisyatifaa.2025@gmail.com
# eisyatifaa.2025@gmail.com
# eisyatifaa.2025@gmail.com

# %%
email_user_1 = "eisyatifaa.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# eisyatifaa.2025@gmail.com
# eisyatifaa.2025@gmail.com
# eisyatifaa.2025@gmail.com

# %% [markdown]
# #Peraturan penamaan variabel

# %%
#Hanya di perbolehkan menggunakan huruf,angka,dan under score
email user 2 = "eisyatifaa.2025@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-1059092441.py", line 2
#     email user 2 = "eisyatifaa.2025@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 = "eisyatifaa.2025@gmail.com"

print(emailuser2)
# Out:
# eisyatifaa.2025@gmail.com

# %%
#Tidak boleh di dahului angka
3_email_user = "eisyatifaa.2025@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-3404465983.py", line 2
#     3_email_user = "eisyatifaa.2025@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "Willytaulany@gmail.com"

print(email_user_3)
# Out:
# Willytaulany@gmail.com

# %%
#Tidak boleh menggunakan kata kunci pyhon
for = "Himamhimawan@gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-390443103.py", line 2
#     for = "Himamhimawan@gmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Himamhimawan@gmail.com"

print(For)
# Out:
# Himamhimawan@gmail.com

# %%
Print = "Juliawati@gmail.com"

print(Print)
# Out:
# Juliawati@gmail.com

# %%
#tidak error tapi di anjurkan harus deskriptif
_ = "Devandraarnoldi@gmail.com"

# %%
print(_)
# Out:
# Devandraarnoldi@gmail.com

# %%
_ = "Haidarhalilintar@gmail.com"

# %%
print(_)
# Out:
# Haidarhalilintar@gmail.com

# %% [markdown]
# #Assignment

# %%
#Single assignment
nama_mahasiswa_1 = "Alexandrio"

print(nama_mahasiswa_1)
# Out:
# Alexandrio

# %%
#Multiple Assignment

# nama_barang_1 = "rinso"
# nama_barang_2 = "molto"

nama_barang_1,nama_barang_2 = "rinso","molto"

print(nama_barang_1)
print(nama_barang_2)
# Out:
# rinso
# molto

# %%
#Assignment yang sama
nilai_Devandra = nilai_Willy = nilai_dzaki = 100

print(nilai_Devandra)
print(nilai_Willy)
print(nilai_dzaki)
# Out:
# 100
# 100
# 100

# %%
# Menimpa/mengubah nilai variabel

nilai_himam = 95

# %%
print(nilai_himam)
# Out:
# 95

# %%
nilai_himam = 100

# %%
print(nilai_himam)
# Out:
# 100

# %% [markdown]
# #Penggunaan Operator di Pyton

# %%
#Tanpa variabel
print(23+3)
# Out:
# 26

# %%
#Operand disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#hasil operasi disimpan ke dalam variabel
jumlah_roti_swiss = 20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#operand dan hasil oprasi disimpan ke variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

jumlah_roti_swiss = roti_swiss_alex + roti_swiss_nazril

print(jumlah_roti_swiss)
# Out:
# 23

# %% [markdown]
# #Operator aritmatika

# %%
buku_tulis_himam = 55
buku_tulis_vico = 15

# %%
#penjumlahan
total_buku_tulis = buku_tulis_himam + buku_tulis_vico
print(total_buku_tulis)
# Out:
# 70

# %%
#pengurangan
selisi_buku_tulis = buku_tulis_himam - buku_tulis_vico
print(selisi_buku_tulis)
# Out:
# 40

# %%
#perkalian
selisi_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis = selisi_buku_tulis * isi_buku_tulis_perkardus
print(total_buku_tulis)
# Out:
# 30

# %%
#pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3.3333333333333335

# %%
#pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3

# %%
#sisa bagi
sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# 3

# %%
#perpangkatan

sisi = 5
luas_persegi = sisi**2
print(luas_persegi)
# Out:
# 25

# %%
luas_persegi = 36

sisi = luas_persegi ** (1/2)
print(sisi)
# Out:
# 6.0

# %% [markdown]
# #Tipe Variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72.5

type(berat_badan)
float
# Out:
# float

# %%
nama = "Dzaki"

type(nama)
str
# Out:
# str

# %%
lulus = True
type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = -10.0
type(titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #Konversi Tipe Data

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool

# %% [markdown]
# #Fungsi Input()

# %%
panjang_balok = float(input("Masukkan nilai panjang dari balok (cm)"))
lebar_balok = float(input("Masukkan nilai lebar dari balok (cm)"))
tinggi_balok = float(input("Masukkan nilai tinggi dari balok (cm)"))

volume_balok = panjang_balok * lebar_balok * tinggi_balok
print(f"volume balok yaitu {volume_balok} cm^3")
# Out:
# Masukkan nilai panjang dari balok (cm)7
# Masukkan nilai lebar dari balok (cm)8
# Masukkan nilai tinggi dari balok (cm)9
# volume balok yaitu 504.0 cm^3
